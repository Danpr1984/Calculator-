# %%
# !pip install numpy

# !pip install pandas

# !pip install seaborn

# !pip install statsmodels

# !pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
categories = ['a', 'b', 'c']
categories
# Out:
# ['a', 'b', 'c']

# %%
my_list = [-1, -2, -3]
my_list
# Out:
# [-1, -2, -3]

# %%
arr = np.array([100,99,98])
arr
# Out:
# array([100,  99,  98])

# %%
my_dict = {'Item1': 999, 'Item2': 888, 'Item3': 777}
my_dict
# Out:
# {'Item1': 999, 'Item2': 888, 'Item3': 777}

# %%
# pd.Series() based on a python list. Argument is data. Indexed 0, 1, 2.

# %%
pd.Series(data=my_list)
# Out:
# 0   -1
# 1   -2
# 2   -3
# dtype: int64

# %%
pd.Series(data = categories)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=my_list, index=categories)
# Out:
# a   -1
# b   -2
# c   -3
# dtype: int64

# %%
pd.Series(data=my_list, index=categories, name = "My First Series")
# Out:
# a   -1
# b   -2
# c   -3
# Name: My First Series, dtype: int64

# %%
pd.Series(data=categories)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data=arr)
# Out:
# 0    100
# 1     99
# 2     98
# dtype: int64

# %%
pd.Series(index=categories, data=arr, name = 'Array')
# Out:
# a    100
# b     99
# c     98
# Name: Array, dtype: int64

# %%
#Data frames Set of series put together to share the same index.

# %%
np.random.seed(101)
df = pd.DataFrame(data = np.random.randn(5,4),
                  index = ['A','B','C','D','E'],
                  columns = ['Col1','Col2','Col3','Col4'])
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
dict1 = {'Item1':[9,9,7,1], 'Item2':[8,6,68,8], 'Item3':[1,2,7,8]}
dict1
# Out:
# {'Item1': [9, 9, 7, 1], 'Item2': [8, 6, 68, 8], 'Item3': [1, 2, 7, 8]}

# %%
df = pd.DataFrame(data=dict1)
df
# Out:
#    Item1  Item2  Item3
# 0      9      8      1
# 1      9      6      2
# 2      7     68      7
# 3      1      8      8

# %%
print(df)
# Out:
#    Item1  Item2  Item3
# 0      9      8      1
# 1      9      6      2
# 2      7     68      7
# 3      1      8      8

# %%
np.random.seed(101)
df = pd.DataFrame(data=np.random.randn(10,40))
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318 -0.848077
# 1 -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.156598 -0.031579
# 2 -1.467514 -0.494095 -0.162535  0.485809  0.392489  0.221491 -0.855196
# 3  0.586847 -1.621348  0.677535  0.026105 -1.678284  0.333973 -0.532471
# 4  0.093628  1.240813 -1.097693 -1.908009 -0.380104 -1.666059 -2.736995
# 5 -0.279510  1.062710  1.752014  0.695547  0.153661  0.167638 -0.765930
# 6 -1.409126  0.870907  1.585812  0.929658 -0.550876  0.942045 -0.975349
# 7 -1.087436 -2.567767  0.661029 -0.332921 -0.928602  1.715950 -0.468756
# 8 -0.181904 -0.603235 -2.552660 -0.031927  1.407189  0.060971 -1.542393
# 9 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.190511  0.231609
#
#          7         8         9   ...        30        31        32        33  \
# 0  0.605965 -2.018168  0.740122  ...  0.638787  0.329646 -0.497104 -0.754070
# ...

# %%
print(df)
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318 -0.848077
# 1 -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.156598 -0.031579
# 2 -1.467514 -0.494095 -0.162535  0.485809  0.392489  0.221491 -0.855196
# 3  0.586847 -1.621348  0.677535  0.026105 -1.678284  0.333973 -0.532471
# 4  0.093628  1.240813 -1.097693 -1.908009 -0.380104 -1.666059 -2.736995
# 5 -0.279510  1.062710  1.752014  0.695547  0.153661  0.167638 -0.765930
# 6 -1.409126  0.870907  1.585812  0.929658 -0.550876  0.942045 -0.975349
# 7 -1.087436 -2.567767  0.661029 -0.332921 -0.928602  1.715950 -0.468756
# 8 -0.181904 -0.603235 -2.552660 -0.031927  1.407189  0.060971 -1.542393
# 9 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.190511  0.231609
#
#          7         8         9   ...        30        31        32        33  \
# 0  0.605965 -2.018168  0.740122  ...  0.638787  0.329646 -0.497104 -0.754070
# ...

# %%
df2 = df.copy()

# %%
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318 -0.848077
# 1 -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.156598 -0.031579
# 2 -1.467514 -0.494095 -0.162535  0.485809  0.392489  0.221491 -0.855196
# 3  0.586847 -1.621348  0.677535  0.026105 -1.678284  0.333973 -0.532471
# 4  0.093628  1.240813 -1.097693 -1.908009 -0.380104 -1.666059 -2.736995
# 5 -0.279510  1.062710  1.752014  0.695547  0.153661  0.167638 -0.765930
# 6 -1.409126  0.870907  1.585812  0.929658 -0.550876  0.942045 -0.975349
# 7 -1.087436 -2.567767  0.661029 -0.332921 -0.928602  1.715950 -0.468756
# 8 -0.181904 -0.603235 -2.552660 -0.031927  1.407189  0.060971 -1.542393
# 9 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.190511  0.231609
#
#          7         8         9   ...        30        31        32        33  \
# 0  0.605965 -2.018168  0.740122  ...  0.638787  0.329646 -0.497104 -0.754070
# ...

# %%
df2
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318 -0.848077
# 1 -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.156598 -0.031579
# 2 -1.467514 -0.494095 -0.162535  0.485809  0.392489  0.221491 -0.855196
# 3  0.586847 -1.621348  0.677535  0.026105 -1.678284  0.333973 -0.532471
# 4  0.093628  1.240813 -1.097693 -1.908009 -0.380104 -1.666059 -2.736995
# 5 -0.279510  1.062710  1.752014  0.695547  0.153661  0.167638 -0.765930
# 6 -1.409126  0.870907  1.585812  0.929658 -0.550876  0.942045 -0.975349
# 7 -1.087436 -2.567767  0.661029 -0.332921 -0.928602  1.715950 -0.468756
# 8 -0.181904 -0.603235 -2.552660 -0.031927  1.407189  0.060971 -1.542393
# 9 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.190511  0.231609
#
#          7         8         9   ...        30        31        32        33  \
# 0  0.605965 -2.018168  0.740122  ...  0.638787  0.329646 -0.497104 -0.754070
# ...

# %%
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318 -0.848077
# 1 -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.156598 -0.031579
# 2 -1.467514 -0.494095 -0.162535  0.485809  0.392489  0.221491 -0.855196
# 3  0.586847 -1.621348  0.677535  0.026105 -1.678284  0.333973 -0.532471
# 4  0.093628  1.240813 -1.097693 -1.908009 -0.380104 -1.666059 -2.736995
# 5 -0.279510  1.062710  1.752014  0.695547  0.153661  0.167638 -0.765930
# 6 -1.409126  0.870907  1.585812  0.929658 -0.550876  0.942045 -0.975349
# 7 -1.087436 -2.567767  0.661029 -0.332921 -0.928602  1.715950 -0.468756
# 8 -0.181904 -0.603235 -2.552660 -0.031927  1.407189  0.060971 -1.542393
# 9 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.190511  0.231609
#
#          7         8         9   ...        30        31        32        33  \
# 0  0.605965 -2.018168  0.740122  ...  0.638787  0.329646 -0.497104 -0.754070
# ...

# %%
df['Col1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df['Col1']
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'Col1'

# %%
df[['Col1', 'Col2']]
# Out:
#        Col1      Col2
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df.filter(['Col1', 'Col2'], axis = 1)
# Out:
#        Col1      Col2
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757

# %%
df['Col5'] = df['Col1'] + df['Col3']
df
# Out:
#        Col1      Col2      Col3      Col4      Col5
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# ### Drop Columns use Axis = 0

# %%
df.drop(labels = ['Col5'], axis = 1)
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#        Col1      Col2      Col3      Col4      Col5
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# ### To save changes we use inplace = True

# %%
df.drop(labels = ['Col5'], axis = 1, inplace = True)

# %%
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ### Drop rows:

# %%
df.drop(labels=['A', 'E'], axis = 0)
# Out:
#        Col1      Col2      Col3      Col4
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318 -0.848077
# 1 -0.993263  0.196800 -1.136645  0.000366  1.025984 -0.156598 -0.031579
# 2 -1.467514 -0.494095 -0.162535  0.485809  0.392489  0.221491 -0.855196
# 3  0.586847 -1.621348  0.677535  0.026105 -1.678284  0.333973 -0.532471
# 4  0.093628  1.240813 -1.097693 -1.908009 -0.380104 -1.666059 -2.736995
# 5 -0.279510  1.062710  1.752014  0.695547  0.153661  0.167638 -0.765930
# 6 -1.409126  0.870907  1.585812  0.929658 -0.550876  0.942045 -0.975349
# 7 -1.087436 -2.567767  0.661029 -0.332921 -0.928602  1.715950 -0.468756
# 8 -0.181904 -0.603235 -2.552660 -0.031927  1.407189  0.060971 -1.542393
# 9 -0.308472 -0.842066 -0.831162 -0.493941  0.552794 -0.190511  0.231609
#
#          7         8         9   ...        30        31        32        33  \
# 0  0.605965 -2.018168  0.740122  ...  0.638787  0.329646 -0.497104 -0.754070
# ...

# %%
df.loc['A']
# Out:
# Col1    2.706850
# Col2    0.628133
# Col3    0.907969
# Col4    0.503826
# Name: A, dtype: float64

# %% [markdown]
# ### When slicing using .loc, the last value is included which is not usual in python.

# %%
df.loc['A':'D']
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df.loc['A':'C']
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df.loc['A':'C']
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df.loc[['A','D']]
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df.loc['D', 'Col3']
# Out:
# -0.9332372163009188

# %%
df.loc[['A', 'E'], ['Col1', 'Col3']]
# Out:
#        Col1      Col3
# A  2.706850  0.907969
# E  0.190794  2.605967

# %%
df.loc[['A'], ['Col2', 'Col4']]
# Out:
#        Col2      Col4
# A  0.628133  0.503826

# %% [markdown]
# ### iloc subsets data frame based on index location

# %%
df.iloc[0]
# Out:
# Col1    2.706850
# Col2    0.628133
# Col3    0.907969
# Col4    0.503826
# Name: A, dtype: float64

# %%
df.iloc[:3, :4]
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df.iloc[-3:, -1:]
# Out:
#        Col4
# C -0.589001
# D  0.955057
# E  0.683509

# %%
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ### query() Boolean approach.

# %%
df[df['Col4']>1]
# Out:
# Empty DataFrame
# Columns: [Col1, Col2, Col3, Col4]
# Index: []

# %%
df.query("Col4>0.6")
# Out:
#        Col1      Col2      Col3      Col4
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.query('Col4> 0 and Col1 > 0.5')
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965

# %%
df.query('Col2 > 0.8 or Col2 < 0 and Col1 > 0.5')
# Out:
#        Col1      Col2      Col3      Col4
# B  0.651118 -0.319318 -0.848077  0.605965
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.query('(Col2 > 0.8 or Col2 < 0) and Col1 > 0.5')
# Out:
#        Col1      Col2      Col3      Col4
# B  0.651118 -0.319318 -0.848077  0.605965

# %%
df.query('(Col3>0.4 or Col4>0.7) and Col1<0.2')
# Out:
#        Col1      Col2      Col3      Col4
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ### Index and MultiIndex

# %%
df
# Out:
#        Col1      Col2      Col3      Col4
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.reset_index()
# Out:
#   index      Col1      Col2      Col3      Col4
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(drop = True, inplace = True)
df
# Out:
#        Col1      Col2      Col3      Col4
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509

# %%
df['Col5'] = ['Part1', 'Part2', 'Part3', 'Item1', 'Item2']
df
# Out:
#        Col1      Col2      Col3      Col4   Col5
# 0  2.706850  0.628133  0.907969  0.503826  Part1
# 1  0.651118 -0.319318 -0.848077  0.605965  Part2
# 2 -2.018168  0.740122  0.528813 -0.589001  Part3
# 3  0.188695 -0.758872 -0.933237  0.955057  Item1
# 4  0.190794  1.978757  2.605967  0.683509  Item2

# %%
df.set_index('Col5', inplace=True)
df
# Out:
#            Col1      Col2      Col3      Col4
# Col5
# Part1  2.706850  0.628133  0.907969  0.503826
# Part2  0.651118 -0.319318 -0.848077  0.605965
# Part3 -2.018168  0.740122  0.528813 -0.589001
# Item1  0.188695 -0.758872 -0.933237  0.955057
# Item2  0.190794  1.978757  2.605967  0.683509

# %%
df.index
# Out:
# Index(['Part1', 'Part2', 'Part3', 'Item1', 'Item2'], dtype='object', name='Col5')

# %%
df
# Out:
#            Col1      Col2      Col3      Col4
# Col5
# Part1  2.706850  0.628133  0.907969  0.503826
# Part2  0.651118 -0.319318 -0.848077  0.605965
# Part3 -2.018168  0.740122  0.528813 -0.589001
# Item1  0.188695 -0.758872 -0.933237  0.955057
# Item2  0.190794  1.978757  2.605967  0.683509

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
np.random.seed(seed=13)
df = pd.DataFrame(data={'Col1':np.random.randint(low=10, high=20, size=10),
                        'Col2':np.random.randint(low=-10, high=0, size=10),
                        'Category1':np.random.choice(['X', 'Y', 'Z'], size=10),
                        'Category2': np.random.choice(['a','b','c','d','e','f','g'], size=10)}
                        )
df
# Out:
#    Col1  Col2 Category1 Category2
# 0    12    -4         Y         e
# 1    10    -5         Y         f
# 2    10    -1         Z         d
# 3    16    -6         X         f
# 4    12    -8         X         a
# 5    14   -10         X         d
# 6    19    -7         X         c
# 7    13    -5         Z         a
# 8    14    -7         Z         f
# 9    12    -4         Z         b

# %%
df.set_index(['Category1', 'Category2'], inplace=True)
df
# Out:
#                      Col1  Col2
# Category1 Category2
# Y         e            12    -4
#           f            10    -5
# Z         d            10    -1
# X         f            16    -6
#           a            12    -8
#           d            14   -10
#           c            19    -7
# Z         a            13    -5
#           f            14    -7
#           b            12    -4

# %%
df.index
# Out:
# MultiIndex([('Y', 'e'),
#             ('Y', 'f'),
#             ('Z', 'd'),
#             ('X', 'f'),
#             ('X', 'a'),
#             ('X', 'd'),
#             ('X', 'c'),
#             ('Z', 'a'),
#             ('Z', 'f'),
#             ('Z', 'b')],
#            names=['Category1', 'Category2'])

# %%
df.index.names
# Out:
# FrozenList(['Category1', 'Category2'])

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   Category1 Category2  Col1  Col2
# 0         Y         e    12    -4
# 1         Y         f    10    -5
# 2         Z         d    10    -1
# 3         X         f    16    -6
# 4         X         a    12    -8
# 5         X         d    14   -10
# 6         X         c    19    -7
# 7         Z         a    13    -5
# 8         Z         f    14    -7
# 9         Z         b    12    -4

# %%
# !ls
# Out:
#  app.ipynb  'Pandas training.ipynb'   testpandas.xlsx   Untitled.ipynb

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/flights.csv',
                 index_col=['year'])
df
# Out:
#           month  passengers
# year
# 1949    January         112
# 1949   February         118
# 1949      March         132
# 1949      April         129
# 1949        May         121
# ...         ...         ...
# 1960     August         606
# 1960  September         508
# 1960    October         461
# 1960   November         390
# 1960   December         432
#
# [144 rows x 2 columns]

# %%
df
# Out:
#           month  passengers
# year
# 1949    January         112
# 1949   February         118
# 1949      March         132
# 1949      April         129
# 1949        May         121
# ...         ...         ...
# 1960     August         606
# 1960  September         508
# 1960    October         461
# 1960   November         390
# 1960   December         432
#
# [144 rows x 2 columns]

# %%
df.index
# Out:
# Index([1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949,
#        ...
#        1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960],
#       dtype='int64', name='year', length=144)

# %%
# !ls
# Out:
#  app.ipynb  'Pandas training.ipynb'   testpandas.xlsx   Untitled.ipynb

# %%
df.to_csv('flights.csv')

# %%
# !ls
# Out:
#  app.ipynb    'Pandas training.ipynb'   Untitled.ipynb
#  flights.csv   testpandas.xlsx

# %%
# !pwd
# Out:
# /workspace/Calculator-

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/penguins.csv')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.to_csv('test_pandas_er.xlsx')

# %%
# !ls
# Out:
# '~$test_pandas_er.xlsx'  'Pandas training.ipynb'   Untitled.ipynb
#  app.ipynb		  practice_example.csv
#  flights.csv		  test_pandas_er.xlsx

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# !pip install --upgrade openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
import openpyxl
wb = openpyxl.load_workbook('test_pandas_er.xlsx')

# %%
df = wb

# %%
df

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.DataFrame(data, columns=columns)
#
# NameError: name 'data' is not defined

# %%
sheet = wb['Sheet1']

# %%
df = pd.DataFrame(data, columns=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.DataFrame(data, columns=columns)
#
# NameError: name 'data' is not defined

# %%
data = sheet.values
columns = next(data)
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#           None  Enero  Febrero  Marzo  Abril
# 0        Hotel      1        2      3      4
# 1  Restaurante      2        3      4      5

# %%
df = pd.read_excel('testpandas_1.xlsx')

# %%
df
# Out:
#                            Unnamed: 0          Enero        Febrero  \
# 0          Ingresos Bar y Restaurante  586384.340000  366758.174200
# 1   Ventas x Servicios de Restaurante  409040.029800  220054.904500
# 2           Ventas x Servicios de Bar  177344.310200  146703.269700
# 3            Ingreso por Habitaciones  669959.620000  598394.920000
# 4           Servicios de Habitaciones  669959.620000  598394.920000
# 5                  Restaurante gastos  102580.802851   46291.776484
# 6                     Mariscos gastos   46858.565000   42942.430000
# 7                          Bar gastos   80784.790000   58899.850000
# 8                        Hotel gastos   79331.580000   60886.140000
# 9                Menos Costo de Venta  309555.737851  209020.196484
# 10           Gastos de Administracion  268254.984000  204772.279500
# 11                     Salarios Fijos  156901.904000  144650.949500
# 12                Salarios Eventuales   36725.000000   30034.950000
# ...

# %%
df_filtered = df[df['Unnamed: 0'].str.contains('gastos', case=False)]

# %%
df.set_index(['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#                                            Enero        Febrero  \
# Unnamed: 0
# Ingresos Bar y Restaurante         586384.340000  366758.174200
# Ventas x Servicios de Restaurante  409040.029800  220054.904500
# Ventas x Servicios de Bar          177344.310200  146703.269700
# Ingreso por Habitaciones           669959.620000  598394.920000
# Servicios de Habitaciones          669959.620000  598394.920000
# Restaurante gastos                 102580.802851   46291.776484
# Mariscos gastos                     46858.565000   42942.430000
# Bar gastos                          80784.790000   58899.850000
# Hotel gastos                        79331.580000   60886.140000
# Menos Costo de Venta               309555.737851  209020.196484
# Gastos de Administracion           268254.984000  204772.279500
# Salarios Fijos                     156901.904000  144650.949500
# Salarios Eventuales                 36725.000000   30034.950000
# ...

# %%
df['Total'] = df.sum(axis=1)
df
# Out:
#                                            Enero        Febrero  \
# Unnamed: 0
# Ingresos Bar y Restaurante         586384.340000  366758.174200
# Ventas x Servicios de Restaurante  409040.029800  220054.904500
# Ventas x Servicios de Bar          177344.310200  146703.269700
# Ingreso por Habitaciones           669959.620000  598394.920000
# Servicios de Habitaciones          669959.620000  598394.920000
# Restaurante gastos                 102580.802851   46291.776484
# Mariscos gastos                     46858.565000   42942.430000
# Bar gastos                          80784.790000   58899.850000
# Hotel gastos                        79331.580000   60886.140000
# Menos Costo de Venta               309555.737851  209020.196484
# Gastos de Administracion           268254.984000  204772.279500
# Salarios Fijos                     156901.904000  144650.949500
# Salarios Eventuales                 36725.000000   30034.950000
# ...

# %%
df = df.rename_axis('Category')

# %%
df
# Out:
#                                            Enero        Febrero  \
# Category
# Ingresos Bar y Restaurante         586384.340000  366758.174200
# Ventas x Servicios de Restaurante  409040.029800  220054.904500
# Ventas x Servicios de Bar          177344.310200  146703.269700
# Ingreso por Habitaciones           669959.620000  598394.920000
# Servicios de Habitaciones          669959.620000  598394.920000
# Restaurante gastos                 102580.802851   46291.776484
# Mariscos gastos                     46858.565000   42942.430000
# Bar gastos                          80784.790000   58899.850000
# Hotel gastos                        79331.580000   60886.140000
# Menos Costo de Venta               309555.737851  209020.196484
# Gastos de Administracion           268254.984000  204772.279500
# Salarios Fijos                     156901.904000  144650.949500
# Salarios Eventuales                 36725.000000   30034.950000
# ...

# %%
df_filtered = df[df.index.str.contains('gastos', case=False)]

# %%
df_filtered
# Out:
#                                   Enero        Febrero          Marzo  \
# Category
# Restaurante gastos        102580.802851   46291.776484  174371.480000
# Mariscos gastos            46858.565000   42942.430000   38015.000000
# Bar gastos                 80784.790000   58899.850000  100481.560000
# Hotel gastos               79331.580000   60886.140000   28584.950000
# Gastos de Administracion  268254.984000  204772.279500  261645.089201
# Gastos del personal            0.000000       0.000000       0.000000
# Gastos Generales          175760.237836  184788.539198  148956.245000
# Gastos de Publicidad        9987.668480   21330.721207       0.000000
# Gastos Financieros         41297.976760   37721.058669   12436.960000
#
#                                   Abril          Total
# Category
# Restaurante gastos         81602.322700  404846.382035
# Mariscos gastos            65011.480000  192827.475000
# Bar gastos                116160.301000  356326.501000
# ...

# %% [markdown]
# ### Missing Data df.isnull() for missing data, df.dropna() to drop and df.fillna() to fill missing data

# %%
np.random.seed(seed=2)
np.random.choice([1,2,3], size=7)
# Out:
# array([1, 2, 1, 3, 3, 1, 3])

# %%
np.random.seed(seed=1)
df=pd.DataFrame(data={'A':np.random.choice([1,2,3,np.nan], size=3),
                      'B':np.random.choice([1, np.nan], size=3),
                      'C':np.random.choice([10,20], size=3),  
                      })
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1   True   True  False
# 2  False   True  False

# %%
df.isnull().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df.species
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
df.species
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
species_counts = df['species'].value_counts()

# %%
species_counts
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df.dropna()
# Out:
#      A    B   C
# 0  2.0  1.0  20

# %%
df.dropna(axis=1)
# Out:
#     C
# 0  20
# 1  20
# 2  20

# %%
df.dropna(thresh=1)
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df.dropna(subset=['A'])
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 2  1.0  NaN  20

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df.dropna(subset=['bill_length_mm'])
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 4             4  Adelie  Torgersen            36.7           19.3
# 5             5  Adelie  Torgersen            39.3           20.6
# ..          ...     ...        ...             ...            ...
# 338         338  Gentoo     Biscoe            47.2           13.7
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  NaN  NaN  20
# 2  1.0  NaN  20

# %%
df.fillna(value=-4)
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1 -4.0 -4.0  20
# 2  1.0 -4.0  20

# %%
df['A'].fillna(value=df['A'].sum(),inplace=True)
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df['A'].fillna(value=df['A'].mean(),inplace=True)
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df
# Out:
#      A    B   C
# 0  2.0  1.0  20
# 1  1.5  NaN  20
# 2  1.0  NaN  20

# %%
df = pd.read_csv('practice_example.csv')

# %%
df['flipper_length_mm'].fillna(value=df['flipper_length_mm'].mean(), inplace=True)
df['sex'].fillna(value='MALE', inplace=True)
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0           181.000000       3750.0    MALE
# 1           186.000000       3800.0  FEMALE
# ...

# %% [markdown]
# ## Data Exploration

# %%
df = pd.DataFrame (data={'Col1':np.random.randint (low=0, high=50, size=10),
                         'Col2' :np.random. randn(10),
                         'Col3': ['A', 'B', 'C', 'A', 'A', 'C', 'D', 'B', 'A', 'A'],
                         'Col4' :np.random. choice   ([True, False],size=10),
                         'Co15':np.random. randint (low=1, high=4, size=10)},
                    index=pd. date_range (start='01/01/2021', periods=10, freq= 'M'))

df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    49  1.735406    A  False     3
# 2021-02-28    41  1.125412    B   True     2
# 2021-03-31    10 -0.182304    C   True     1
# 2021-04-30     9  0.560422    A   True     2
# 2021-05-31    10  0.165073    A   True     2
# 2021-06-30    22  0.762652    C   True     2
# 2021-07-31     6 -0.328121    D  False     2
# 2021-08-31     4  3.431369    B  False     3
# 2021-09-30    39 -0.062790    A  False     1
# 2021-10-31    29 -0.767343    A  False     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2021-01-31 to 2021-10-31
# Freq: M
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    10 non-null     int64
#  1   Col2    10 non-null     float64
#  2   Col3    10 non-null     object
#  3   Col4    10 non-null     bool
#  4   Co15    10 non-null     int64
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 410.0+ bytes

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.head(n=3)
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31     6  0.757859    A  False     3
# 2021-02-28    14  0.427271    B  False     3
# 2021-03-31    19  1.162194    C  False     1

# %%
df.tail()
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-06-30    33  0.717998    C  False     2
# 2021-07-31    33 -0.409839    D   True     2
# 2021-08-31    11 -2.465459    B   True     2
# 2021-09-30    40  0.733871    A  False     3
# 2021-10-31    44 -1.451487    A   True     1

# %%
df.dtypes
# Out:
# Col1      int64
# Col2    float64
# Col3     object
# Col4       bool
# Co15      int64
# dtype: object

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['Col1', 'Col2', 'Col3', 'Col4', 'Co15'], dtype='object')

# %%
# !pip install openpyxl
df = pd.read_excel('testpandas_1.xlsx')
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().system('pip install openpyxl')
# ----> 2 df = pd.read_excel('testpandas_1.xlsx')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#                            Unnamed: 0          Enero        Febrero  \
# 0          Ingresos Bar y Restaurante  586384.340000  366758.174200
# 1   Ventas x Servicios de Restaurante  409040.029800  220054.904500
# 2           Ventas x Servicios de Bar  177344.310200  146703.269700
# 3            Ingreso por Habitaciones  669959.620000  598394.920000
# 4           Servicios de Habitaciones  669959.620000  598394.920000
# 5                  Restaurante gastos  102580.802851   46291.776484
# 6                     Mariscos gastos   46858.565000   42942.430000
# 7                          Bar gastos   80784.790000   58899.850000
# 8                        Hotel gastos   79331.580000   60886.140000
# 9                Menos Costo de Venta  309555.737851  209020.196484
# 10           Gastos de Administracion  268254.984000  204772.279500
# 11                     Salarios Fijos  156901.904000  144650.949500
# 12                Salarios Eventuales   36725.000000   30034.950000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Enero', 'Febrero', 'Marzo', 'Abril'], dtype='object')

# %%
df['Abril'].nunique()
# Out:
# 40

# %%
df['Febrero']
# Out:
# 0     366758.174200
# 1     220054.904500
# 2     146703.269700
# 3     598394.920000
# 4     598394.920000
# 5      46291.776484
# 6      42942.430000
# 7      58899.850000
# 8      60886.140000
# 9     209020.196484
# 10    204772.279500
# 11    144650.949500
# 12     30034.950000
# 13     28663.570000
# 14      1422.810000
# 15         0.000000
# 16         0.000000
# 17         0.000000
# 18    184788.539198
# 19     32122.222842
# 20      2052.085650
# 21      2888.900754
# 22      4646.430393
# 23     31633.580000
# 24      1288.000000
# 25     28956.250000
# 26      9532.450000
# 27      5548.000000
# 28      3280.000000
# 29     18545.000000
# 30     11711.000000
# 31      2923.768050
# 32      6761.130000
# 33       217.557399
# 34      6231.790000
# 35      8030.374110
# 36      6570.000000
# 37      1850.000000
# 38         0.000000
# 39     21330.721207
# 40      6830.721207
# 41     14500.000000
# 42     37721.058669
# 43     22677.000402
# 44      5392.528267
# ...

# %%
df['Febrero'].nunique()
# Out:
# 42

# %%
df['Febrero'].unique()
# Out:
# array([3.66758174e+05, 2.20054905e+05, 1.46703270e+05, 5.98394920e+05,
#        4.62917765e+04, 4.29424300e+04, 5.88998500e+04, 6.08861400e+04,
#        2.09020196e+05, 2.04772280e+05, 1.44650950e+05, 3.00349500e+04,
#        2.86635700e+04, 1.42281000e+03, 0.00000000e+00, 1.84788539e+05,
#        3.21222228e+04, 2.05208565e+03, 2.88890075e+03, 4.64643039e+03,
#        3.16335800e+04, 1.28800000e+03, 2.89562500e+04, 9.53245000e+03,
#        5.54800000e+03, 3.28000000e+03, 1.85450000e+04, 1.17110000e+04,
#        2.92376805e+03, 6.76113000e+03, 2.17557399e+02, 6.23179000e+03,
#        8.03037411e+03, 6.57000000e+03, 1.85000000e+03, 2.13307212e+04,
#        6.83072121e+03, 1.45000000e+04, 3.77210587e+04, 2.26770004e+04,
#        5.39252827e+03, 9.65153000e+03])

# %%
df['Febrero'].value_counts()
# Out:
# Febrero
# 0.000000         5
# 598394.920000    2
# 366758.174200    1
# 6231.790000      1
# 5548.000000      1
# 3280.000000      1
# 18545.000000     1
# 11711.000000     1
# 2923.768050      1
# 6761.130000      1
# 217.557399       1
# 8030.374110      1
# 28956.250000     1
# 6570.000000      1
# 1850.000000      1
# 21330.721207     1
# 6830.721207      1
# 14500.000000     1
# 37721.058669     1
# 22677.000402     1
# 5392.528267      1
# 9532.450000      1
# 1288.000000      1
# 220054.904500    1
# 144650.949500    1
# 146703.269700    1
# 46291.776484     1
# 42942.430000     1
# 58899.850000     1
# 60886.140000     1
# 209020.196484    1
# 204772.279500    1
# 30034.950000     1
# 31633.580000     1
# 28663.570000     1
# 1422.810000      1
# 184788.539198    1
# 32122.222842     1
# 2052.085650      1
# 2888.900754      1
# 4646.430393      1
# 9651.530000      1
# Name: count, dtype: int64

# %%
df = pd.read_csv('practice_example.csv')

# %%
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df['island'].value_counts(normalize=True)
# Out:
# island
# Biscoe       0.488372
# Dream        0.360465
# Torgersen    0.151163
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   171.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      0.000000       32.100000      13.100000         172.000000
# 25%     85.750000       39.225000      15.600000         190.000000
# 50%    171.500000       44.450000      17.300000         197.000000
# 75%    257.250000       48.500000      18.700000         213.000000
# max    343.000000       59.600000      21.500000         231.000000
#
#        body_mass_g
# count   342.000000
# mean   4201.754386
# std     801.954536
# min    2700.000000
# 25%    3550.000000
# 50%    4050.000000
# 75%    4750.000000
# max    6300.000000

# %%
df.describe()
# Out:
#                Enero        Febrero          Marzo          Abril
# count      46.000000      47.000000      47.000000      47.000000
# mean    89617.415866   69054.718692   85454.812519   87683.520949
# std    171948.330693  136458.711311  178071.246350  164228.111655
# min         0.000000       0.000000       0.000000       0.000000
# 25%      3054.246669    3101.884025       0.000000    3310.625500
# 50%     11492.715000   11711.000000    6235.420000   12218.027120
# 75%     71255.062500   44617.103242   44738.995000   69393.052000
# max    669959.620000  598394.920000  767031.240961  613417.300800

# %%
df.describe(include='all')
# Out:
#             Col1       Col2 Col3   Col4       Co15
# count   10.00000  10.000000   10     10  10.000000
# unique       NaN        NaN    4      2        NaN
# top          NaN        NaN    A  False        NaN
# freq         NaN        NaN    5      7        NaN
# mean    27.30000   0.119580  NaN    NaN   1.800000
# std     12.53484   0.657876  NaN    NaN   1.032796
# min      6.00000  -0.699465  NaN    NaN   1.000000
# 25%     21.25000  -0.362221  NaN    NaN   1.000000
# 50%     31.00000  -0.051718  NaN    NaN   1.000000
# 75%     35.00000   0.517439  NaN    NaN   3.000000
# max     44.00000   1.443541  NaN    NaN   3.000000

# %%
df = pd.read_csv('practice_example.csv')

# %%
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df.describe(include= 'all')
# Out:
#         Unnamed: 0 species  island  bill_length_mm  bill_depth_mm  \
# count   344.000000     344     344      342.000000     342.000000
# unique         NaN       3       3             NaN            NaN
# top            NaN  Adelie  Biscoe             NaN            NaN
# freq           NaN     152     168             NaN            NaN
# mean    171.500000     NaN     NaN       43.921930      17.151170
# std      99.448479     NaN     NaN        5.459584       1.974793
# min       0.000000     NaN     NaN       32.100000      13.100000
# 25%      85.750000     NaN     NaN       39.225000      15.600000
# 50%     171.500000     NaN     NaN       44.450000      17.300000
# 75%     257.250000     NaN     NaN       48.500000      18.700000
# max     343.000000     NaN     NaN       59.600000      21.500000
#
#         flipper_length_mm  body_mass_g   sex
# count          342.000000   342.000000   333
# unique                NaN          NaN     2
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.corr()
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    49  1.735406    A  False     3
# 2021-02-28    41  1.125412    B   True     2
# 2021-03-31    10 -0.182304    C   True     1
# 2021-04-30     9  0.560422    A   True     2
# 2021-05-31    10  0.165073    A   True     2
# 2021-06-30    22  0.762652    C   True     2
# 2021-07-31     6 -0.328121    D  False     2
# 2021-08-31     4  3.431369    B  False     3
# 2021-09-30    39 -0.062790    A  False     1
# 2021-10-31    29 -0.767343    A  False     2

# %%
df.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.corr(method='pearson')
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame (data={'Col1':np.random.randint (low=0, high=50, size=10),
                         'Col2' :np.random. randn(10),
                         'Col3': ['A', 'B', 'C', 'A', 'A', 'C', 'D', 'B', 'A', 'A'],
                         'Col4' :np.random. choice   ([True, False],size=10),
                         'Co15':np.random. randint (low=1, high=4, size=10)},
                    index=pd. date_range (start='01/01/2021', periods=10, freq= 'M'))

df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    46 -0.086258    A   True     3
# 2021-02-28    27 -2.018954    B   True     2
# 2021-03-31    18  0.072340    C   True     1
# 2021-04-30    40  0.808606    A  False     3
# 2021-05-31    47 -0.694977    A   True     2
# 2021-06-30     3  0.615057    C  False     1
# 2021-07-31     7  0.725565    D  False     3
# 2021-08-31    28 -0.054995    B  False     2
# 2021-09-30    34  0.645898    A  False     3
# 2021-10-31    13  0.257421    A   True     2

# %%
df_example = df.copy()
df_example.head()
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    13 -1.002489    A   True     2
# 2021-02-28    11 -0.163197    B   True     3
# 2021-03-31    35 -1.497050    C   True     2
# 2021-04-30     9 -3.529743    A   True     1
# 2021-05-31    20 -0.538222    A  False     3

# %%
df_example.columns = ['Revenue', 'Rate', 'ProfileCategory', 'Flag', 'Class']
df_example.head()
# Out:
#             Revenue      Rate ProfileCategory   Flag  Class
# 2021-01-31       13 -1.002489               A   True      2
# 2021-02-28       11 -0.163197               B   True      3
# 2021-03-31       35 -1.497050               C   True      2
# 2021-04-30        9 -3.529743               A   True      1
# 2021-05-31       20 -0.538222               A  False      3

# %%
df = pd.read_csv('practice_example.csv')

# %%
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df.rename(columns={'species':'Species',
                   'island':'Island',
                   'sex':'Sex'}, inplace=True)
df
# Out:
#      Unnamed: 0 Species     Island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     Sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    29  1.752319    A  False     2
# 2021-02-28    43  2.323780    B   True     2
# 2021-03-31    21 -1.445201    C   True     2
# 2021-04-30    47 -0.253297    A  False     3
# 2021-05-31    14  1.088703    A  False     2
# 2021-06-30    30 -0.768958    C   True     3
# 2021-07-31    20 -1.662642    D   True     1
# 2021-08-31     0  3.077836    B   True     1
# 2021-09-30    15 -0.260216    A  False     1
# 2021-10-31    43 -0.843199    A  False     1

# %%
df.select_dtypes(include='number')
# Out:
#             Col1      Col2  Co15
# 2021-01-31    29  1.752319     2
# 2021-02-28    43  2.323780     2
# 2021-03-31    21 -1.445201     2
# 2021-04-30    47 -0.253297     3
# 2021-05-31    14  1.088703     2
# 2021-06-30    30 -0.768958     3
# 2021-07-31    20 -1.662642     1
# 2021-08-31     0  3.077836     1
# 2021-09-30    15 -0.260216     1
# 2021-10-31    43 -0.843199     1

# %%
df.select_dtypes(include='object')
# Out:
#            Col3
# 2021-01-31    A
# 2021-02-28    B
# 2021-03-31    C
# 2021-04-30    A
# 2021-05-31    A
# 2021-06-30    C
# 2021-07-31    D
# 2021-08-31    B
# 2021-09-30    A
# 2021-10-31    A

# %%
df.select_dtypes(include='boolean')
# Out:
#              Col4
# 2021-01-31  False
# 2021-02-28   True
# 2021-03-31   True
# 2021-04-30  False
# 2021-05-31  False
# 2021-06-30   True
# 2021-07-31   True
# 2021-08-31   True
# 2021-09-30  False
# 2021-10-31  False

# %%
df.select_dtypes(include=['number', 'boolean'])
# Out:
#             Col1      Col2   Col4  Co15
# 2021-01-31    29  1.752319  False     2
# 2021-02-28    43  2.323780   True     2
# 2021-03-31    21 -1.445201   True     2
# 2021-04-30    47 -0.253297  False     3
# 2021-05-31    14  1.088703  False     2
# 2021-06-30    30 -0.768958   True     3
# 2021-07-31    20 -1.662642   True     1
# 2021-08-31     0  3.077836   True     1
# 2021-09-30    15 -0.260216  False     1
# 2021-10-31    43 -0.843199  False     1

# %%
df1=df.reset_index()

# %%
df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    29  1.752319    A  False     2
# 2021-02-28    43  2.323780    B   True     2
# 2021-03-31    21 -1.445201    C   True     2
# 2021-04-30    47 -0.253297    A  False     3
# 2021-05-31    14  1.088703    A  False     2
# 2021-06-30    30 -0.768958    C   True     3
# 2021-07-31    20 -1.662642    D   True     1
# 2021-08-31     0  3.077836    B   True     1
# 2021-09-30    15 -0.260216    A  False     1
# 2021-10-31    43 -0.843199    A  False     1

# %%
df1
# Out:
#        index  Col1      Col2 Col3   Col4  Co15
# 0 2021-01-31    29  1.752319    A  False     2
# 1 2021-02-28    43  2.323780    B   True     2
# 2 2021-03-31    21 -1.445201    C   True     2
# 3 2021-04-30    47 -0.253297    A  False     3
# 4 2021-05-31    14  1.088703    A  False     2
# 5 2021-06-30    30 -0.768958    C   True     3
# 6 2021-07-31    20 -1.662642    D   True     1
# 7 2021-08-31     0  3.077836    B   True     1
# 8 2021-09-30    15 -0.260216    A  False     1
# 9 2021-10-31    43 -0.843199    A  False     1

# %%
df1.select_dtypes(include='datetime')
# Out:
#        index
# 0 2021-01-31
# 1 2021-02-28
# 2 2021-03-31
# 3 2021-04-30
# 4 2021-05-31
# 5 2021-06-30
# 6 2021-07-31
# 7 2021-08-31
# 8 2021-09-30
# 9 2021-10-31

# %%
df1.select_dtypes(exclude='datetime')
# Out:
#    Col1      Col2 Col3   Col4  Co15
# 0    29  1.752319    A  False     2
# 1    43  2.323780    B   True     2
# 2    21 -1.445201    C   True     2
# 3    47 -0.253297    A  False     3
# 4    14  1.088703    A  False     2
# 5    30 -0.768958    C   True     3
# 6    20 -1.662642    D   True     1
# 7     0  3.077836    B   True     1
# 8    15 -0.260216    A  False     1
# 9    43 -0.843199    A  False     1

# %%
df1.select_dtypes(exclude='boolean')
# Out:
#        index  Col1      Col2 Col3  Co15
# 0 2021-01-31    29  1.752319    A     2
# 1 2021-02-28    43  2.323780    B     2
# 2 2021-03-31    21 -1.445201    C     2
# 3 2021-04-30    47 -0.253297    A     3
# 4 2021-05-31    14  1.088703    A     2
# 5 2021-06-30    30 -0.768958    C     3
# 6 2021-07-31    20 -1.662642    D     1
# 7 2021-08-31     0  3.077836    B     1
# 8 2021-09-30    15 -0.260216    A     1
# 9 2021-10-31    43 -0.843199    A     1

# %%
df=pd.read_csv('practice_example.csv')

# %%
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
df.select_dtypes(include='object')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    MALE
# 1    Adelie  Torgersen  FEMALE
# 2    Adelie  Torgersen  FEMALE
# 3    Adelie  Torgersen     NaN
# 4    Adelie  Torgersen  FEMALE
# ..      ...        ...     ...
# 339  Gentoo     Biscoe     NaN
# 340  Gentoo     Biscoe  FEMALE
# 341  Gentoo     Biscoe    MALE
# 342  Gentoo     Biscoe  FEMALE
# 343  Gentoo     Biscoe    MALE
#
# [344 rows x 3 columns]

# %%
df = pd.DataFrame (data={'Col1':np.random.randint (low=0, high=50, size=10),
                         'Col2' :np.random. randn(10),
                         'Col3': ['A', 'B', 'C', 'A', 'A', 'C', 'D', 'B', 'A', 'A'],
                         'Col4' :np.random. choice   ([True, False],size=10),
                         'Co15':np.random. randint (low=1, high=4, size=10)},
                    index=pd. date_range (start='01/01/2021', periods=10, freq= 'M'))

df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31     1 -0.971421    A   True     1
# 2021-02-28    34 -1.843341    B  False     3
# 2021-03-31    17 -1.454471    C   True     3
# 2021-04-30    35  0.455256    A   True     3
# 2021-05-31     2  0.431169    A  False     2
# 2021-06-30     1  0.982249    C  False     2
# 2021-07-31    44  0.694157    D   True     1
# 2021-08-31     6 -1.133228    B   True     3
# 2021-09-30    30  0.719517    A  False     3
# 2021-10-31    30 -0.015403    A  False     1

# %%
df.to_numpy()
# Out:
# array([[9, 1.0600742225326338, 'A', False, 1],
#        [6, 1.031007101020277, 'B', False, 3],
#        [12, -0.9442618081286438, 'C', False, 1],
#        [27, -1.7240926719470897, 'A', True, 2],
#        [47, 1.0881248713228568, 'A', True, 3],
#        [14, -2.813261002600084, 'C', True, 3],
#        [37, 1.5282378845491336, 'D', False, 3],
#        [5, -2.8972003580708763, 'B', True, 1],
#        [49, -1.07622451612704, 'A', False, 1],
#        [40, -0.4447682282897, 'A', False, 1]], dtype=object)

# %%
df.values
# Out:
# array([[9, 1.0600742225326338, 'A', False, 1],
#        [6, 1.031007101020277, 'B', False, 3],
#        [12, -0.9442618081286438, 'C', False, 1],
#        [27, -1.7240926719470897, 'A', True, 2],
#        [47, 1.0881248713228568, 'A', True, 3],
#        [14, -2.813261002600084, 'C', True, 3],
#        [37, 1.5282378845491336, 'D', False, 3],
#        [5, -2.8972003580708763, 'B', True, 1],
#        [49, -1.07622451612704, 'A', False, 1],
#        [40, -0.4447682282897, 'A', False, 1]], dtype=object)

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of             Col1      Col2 Col3   Col4  Co15
# 2021-01-31     9  1.060074    A  False     1
# 2021-02-28     6  1.031007    B  False     3
# 2021-03-31    12 -0.944262    C  False     1
# 2021-04-30    27 -1.724093    A   True     2
# 2021-05-31    47  1.088125    A   True     3
# 2021-06-30    14 -2.813261    C   True     3
# 2021-07-31    37  1.528238    D  False     3
# 2021-08-31     5 -2.897200    B   True     1
# 2021-09-30    49 -1.076225    A  False     1
# 2021-10-31    40 -0.444768    A  False     1>

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31    26  0.696095    A  False     3
# 2021-02-28    30 -1.295590    B  False     3
# 2021-03-31    28 -0.214541    C  False     2
# 2021-04-30    32 -0.031587    A   True     1
# 2021-05-31     4 -1.161638    A  False     2
# 2021-06-30    49  1.146648    C   True     2
# 2021-07-31    46  0.387797    D  False     2
# 2021-08-31    40 -0.396326    B   True     1
# 2021-09-30    22  1.126240    A   True     2
# 2021-10-31    18 -1.150774    A   True     1

# %%
map_dict = {'A': 'Nice', 'B': 'Super', 'C': 'Amazing', 'D': 'Incredible'}
map_dict
# Out:
# {'A': 'Nice', 'B': 'Super', 'C': 'Amazing', 'D': 'Incredible'}

# %%
df['Col3'].replace(to_replace=map_dict, inplace=True)
df
# Out:
#             Col1      Col2        Col3   Col4  Co15
# 2021-01-31    26  0.696095        Nice  False     3
# 2021-02-28    30 -1.295590       Super  False     3
# 2021-03-31    28 -0.214541     Amazing  False     2
# 2021-04-30    32 -0.031587        Nice   True     1
# 2021-05-31     4 -1.161638        Nice  False     2
# 2021-06-30    49  1.146648     Amazing   True     2
# 2021-07-31    46  0.387797  Incredible  False     2
# 2021-08-31    40 -0.396326       Super   True     1
# 2021-09-30    22  1.126240        Nice   True     2
# 2021-10-31    18 -1.150774        Nice   True     1

# %%
df.dtypes
# Out:
# Col1      int64
# Col2    float64
# Col3     object
# Col4       bool
# Co15      int64
# dtype: object

# %%
df = pd.read_csv('practice_example.csv')
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# ...

# %%
map_dict = {'MALE': 'Male', 'FEMALE': 'Female'}
map_dict
# Out:
# {'MALE': 'Male', 'FEMALE': 'Female'}

# %%
df['sex'].replace(to_replace=map_dict, inplace=True)
df
# Out:
#      Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0             0  Adelie  Torgersen            39.1           18.7
# 1             1  Adelie  Torgersen            39.5           17.4
# 2             2  Adelie  Torgersen            40.3           18.0
# 3             3  Adelie  Torgersen             NaN            NaN
# 4             4  Adelie  Torgersen            36.7           19.3
# ..          ...     ...        ...             ...            ...
# 339         339  Gentoo     Biscoe             NaN            NaN
# 340         340  Gentoo     Biscoe            46.8           14.3
# 341         341  Gentoo     Biscoe            50.4           15.7
# 342         342  Gentoo     Biscoe            45.2           14.8
# 343         343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    Male
# 1                186.0       3800.0  Female
# ...

# %%
df
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31     1 -0.971421    A   True     1
# 2021-02-28    34 -1.843341    B  False     3
# 2021-03-31    17 -1.454471    C   True     3
# 2021-04-30    35  0.455256    A   True     3
# 2021-05-31     2  0.431169    A  False     2
# 2021-06-30     1  0.982249    C  False     2
# 2021-07-31    44  0.694157    D   True     1
# 2021-08-31     6 -1.133228    B   True     3
# 2021-09-30    30  0.719517    A  False     3
# 2021-10-31    30 -0.015403    A  False     1

# %%
df.astype({'Col2':'object'})
# Out:
#             Col1      Col2 Col3   Col4  Co15
# 2021-01-31     1 -0.971421    A   True     1
# 2021-02-28    34 -1.843341    B  False     3
# 2021-03-31    17 -1.454471    C   True     3
# 2021-04-30    35  0.455256    A   True     3
# 2021-05-31     2  0.431169    A  False     2
# 2021-06-30     1  0.982249    C  False     2
# 2021-07-31    44  0.694157    D   True     1
# 2021-08-31     6 -1.133228    B   True     3
# 2021-09-30    30  0.719517    A  False     3
# 2021-10-31    30 -0.015403    A  False     1

# %%
df.dtypes
# Out:
# Col1      int64
# Col2    float64
# Col3     object
# Col4       bool
# Co15      int64
# dtype: object

# %%
df_practice = pd.read_csv('https://raw.githubusercontent.com/Code-Institute-Solutions/sample-datasets/main/titanic.csv')

# %%
df_practice
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_practice[['survived', 'pclass']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
# dtypes: int64(2)
# memory usage: 14.0 KB

# %%
df_practice = df_practice.astype({'survived': bool, 'pclass': object})
df_practice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    bool
#  1   pclass       891 non-null    object
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(3), float64(2), int64(2), object(8)
# memory usage: 86.3+ KB

# %%
df = pd.DataFrame(data={'Name': ['John', 'Marie', 'Joseph', 'John', 'William', 'Marie'],
                        'CustomRate': [1,2,2,4,3,3]})

# %%
df
# Out:
#       Name  CustomRate
# 0     John           1
# 1    Marie           2
# 2   Joseph           2
# 3     John           4
# 4  William           3
# 5    Marie           3

# %%
df.duplicated(subset=['Name'], keep=False)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
df[df.duplicated(subset=['Name'])]
# Out:
#     Name  CustomRate
# 3   John           4
# 5  Marie           3

# %%
df.drop_duplicates(subset=['Name'], inplace=True)
df
# Out:
#       Name  CustomRate
# 0     John           1
# 1    Marie           2
# 2   Joseph           2
# 4  William           3

# %%
np.random.seed(seed=1)
df_practice = pd.DataFrame (data = {'Product_ID': np.random.randint (low=2, high=8, size=12),
                                    'Customer_ID':np.random.randint (low=1, high=8, size=12),
                                    'Value':np.random.randint(low=900, high=999, size=12)

                                    })

df_practice
# Out:
#     Product_ID  Customer_ID  Value
# 0            7            5    928
# 1            5            7    929
# 2            6            2    914
# 3            2            3    950
# 4            3            5    968
# 5            5            7    987
# 6            7            6    987
# 7            2            3    994
# 8            2            5    996
# 9            3            4    986
# 10           6            5    913
# 11           7            3    909

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 4    False
# dtype: bool

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Name, CustomRate]
# Index: []

# %%
df_practice[df_practice.duplicated(subset=['Product_ID', 'Customer_ID'], keep=False)]
# Out:
#    Product_ID  Customer_ID  Value
# 1           5            7    929
# 3           2            3    950
# 5           5            7    987
# 7           2            3    994

# %%
df_practice.drop_duplicates(subset=['Product_ID', 'Customer_ID'], inplace=True)

# %%
df_practice
# Out:
#     Product_ID  Customer_ID  Value
# 0            7            5    928
# 1            5            7    929
# 2            6            2    914
# 3            2            3    950
# 4            3            5    968
# 6            7            6    987
# 8            2            5    996
# 9            3            4    986
# 10           6            5    913
# 11           7            3    909

# %% [markdown]
# ### Time Series

# %%
# Out:
#                   Date  Col1
# 0  2019-10-27 00:00:00    30
# 1  2019-10-27 01:00:00    28
# 2  2019-10-27 02:00:00    29
# 3  2019-10-27 03:00:00    23
# 4  2019-10-27 04:00:00    28
# 5  2019-10-27 05:00:00    28
# 6  2019-10-27 06:00:00    20
# 7  2019-10-27 07:00:00    25
# 8  2019-10-27 08:00:00    33
# 9  2019-10-27 09:00:00    23
# 10 2019-10-27 10:00:00    30
# 11 2019-10-27 11:00:00    31
# 12 2019-10-27 12:00:00    29
# 13 2019-10-27 13:00:00    29
# 14 2019-10-27 14:00:00    30
# 15 2019-10-27 15:00:00    25
# 16 2019-10-27 16:00:00    27
# 17 2019-10-27 17:00:00    26
# 18 2019-10-27 18:00:00    20
# 19 2019-10-27 19:00:00    24
# 20 2019-10-27 20:00:00    32
# 21 2019-10-27 21:00:00    33
# 22 2019-10-27 22:00:00    27
# 23 2019-10-27 23:00:00    34

# %%
df_date['Hour'] = df_date['Date'].dt.hour
df_date['Minute'] = df_date['Date'].dt.minute
df_date['Year'] = df_date['Date'].dt.hour

# %%
df_date
# Out:
#                   Date  Col1  Hour  Minute  Year
# 0  2019-10-27 00:00:00    30     0       0     0
# 1  2019-10-27 01:00:00    28     1       0     1
# 2  2019-10-27 02:00:00    29     2       0     2
# 3  2019-10-27 03:00:00    23     3       0     3
# 4  2019-10-27 04:00:00    28     4       0     4
# 5  2019-10-27 05:00:00    28     5       0     5
# 6  2019-10-27 06:00:00    20     6       0     6
# 7  2019-10-27 07:00:00    25     7       0     7
# 8  2019-10-27 08:00:00    33     8       0     8
# 9  2019-10-27 09:00:00    23     9       0     9
# 10 2019-10-27 10:00:00    30    10       0    10
# 11 2019-10-27 11:00:00    31    11       0    11
# 12 2019-10-27 12:00:00    29    12       0    12
# 13 2019-10-27 13:00:00    29    13       0    13
# 14 2019-10-27 14:00:00    30    14       0    14
# 15 2019-10-27 15:00:00    25    15       0    15
# 16 2019-10-27 16:00:00    27    16       0    16
# 17 2019-10-27 17:00:00    26    17       0    17
# ...

# %%
np.random.seed(seed=1)

df = pd.DataFrame (data={'Price': np.random.randint(low=20, high=35, size=28)},
                     index=pd.date_range (start='27/10/2019 00:00:00', periods=28, freq='D'))

df.head(10)
# Out:
#             Price
# 2019-10-27     25
# 2019-10-28     31
# 2019-10-29     32
# 2019-10-30     28
# 2019-10-31     29
# 2019-11-01     31
# 2019-11-02     25
# 2019-11-03     20
# 2019-11-04     20
# 2019-11-05     21

# %%
df_resample = df.resample(rule='D').sum()
df_resample
# Out:
#             Price
# 2019-10-27     25
# 2019-10-28     31
# 2019-10-29     32
# 2019-10-30     28
# 2019-10-31     29
# 2019-11-01     31
# 2019-11-02     25
# 2019-11-03     20
# 2019-11-04     20
# 2019-11-05     21
# 2019-11-06     32
# 2019-11-07     27
# 2019-11-08     33
# 2019-11-09     32
# 2019-11-10     26
# 2019-11-11     29
# 2019-11-12     22
# 2019-11-13     24
# 2019-11-14     34
# 2019-11-15     25
# 2019-11-16     22
# 2019-11-17     24
# 2019-11-18     31
# 2019-11-19     32
# 2019-11-20     30
# 2019-11-21     32
# 2019-11-22     33
# 2019-11-23     34

# %% [markdown]
# ### Moving Average

# %%
np.random.seed(seed=101)

df = pd.DataFrame (data={'Revenue': np.random.randint(low=200, high=350, size=15)},
                     index=pd.date_range (start='10/10/2020', periods=15, freq='D'))

df
# Out:
#             Revenue
# 2020-10-10      295
# 2020-10-11      211
# 2020-10-12      281
# 2020-10-13      270
# 2020-10-14      263
# 2020-10-15      287
# 2020-10-16      275
# 2020-10-17      337
# 2020-10-18      240
# 2020-10-19      332
# 2020-10-20      263
# 2020-10-21      260
# 2020-10-22      310
# 2020-10-23      205
# 2020-10-24      340

# %%
df_ex = df.copy()
df_ex
# Out:
#             Revenue
# 2020-10-10      295
# 2020-10-11      211
# 2020-10-12      281
# 2020-10-13      270
# 2020-10-14      263
# 2020-10-15      287
# 2020-10-16      275
# 2020-10-17      337
# 2020-10-18      240
# 2020-10-19      332
# 2020-10-20      263
# 2020-10-21      260
# 2020-10-22      310
# 2020-10-23      205
# 2020-10-24      340

# %%
df_ex['RevenueMovingAvg'] = df_ex['Revenue'].rolling(window=4).mean()

# %%
df_ex
# Out:
#             Revenue  RevenueMovingAvg
# 2020-10-10      295               NaN
# 2020-10-11      211               NaN
# 2020-10-12      281               NaN
# 2020-10-13      270            264.25
# 2020-10-14      263            256.25
# 2020-10-15      287            275.25
# 2020-10-16      275            273.75
# 2020-10-17      337            290.50
# 2020-10-18      240            284.75
# 2020-10-19      332            296.00
# 2020-10-20      263            293.00
# 2020-10-21      260            273.75
# 2020-10-22      310            291.25
# 2020-10-23      205            259.50
# 2020-10-24      340            278.75

# %%
df
# Out:
#             Revenue
# 2020-10-10      295
# 2020-10-11      211
# 2020-10-12      281
# 2020-10-13      270
# 2020-10-14      263
# 2020-10-15      287
# 2020-10-16      275
# 2020-10-17      337
# 2020-10-18      240
# 2020-10-19      332
# 2020-10-20      263
# 2020-10-21      260
# 2020-10-22      310
# 2020-10-23      205
# 2020-10-24      340

# %%
df['Percentage Change'] = df['Revenue'].pct_change(periods=1) * 100

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
#   Using cached matplotlib-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# ...
#   Using cached contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached fonttools-4.40.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# ...
#   Using cached kiwisolver-1.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# ...
#   Using cached Pillow-9.5.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.4 MB)
# ...
#   Using cached pyparsing-3.1.0-py3-none-any.whl (102 kB)
# ...

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('diamonds')
df.head(100)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
def sum_of_xyz(df):

    return df['x'] + df['y'] + df['z']

df['xyzSum'] = df.apply(sum_of_xyz, axis=1)

def multiply_price_by_4(price):

    return price * 4

df['price_times_4'] = df[['price']].apply(multiply_price_by_4, axis=1)

df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        xyzSum  price_times_4
# ...

# %% [markdown]
# ### Lambda functions

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df = sns.load_dataset('diamonds')
df.head(50)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
variable = (lambda x: x + 10)(45)
variable
# Out:
# 55

# %%
variable = (lambda x,y: x + 3 * y)(2,1)
variable
# Out:
# 5

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
def my_price_perception(price, cut):
    if cut in ['Premium', 'Ideal'] and price < 2000:
        return 'Worth it, buy now'
    elif price < 1000:
        return 'Buy'
    elif price < 2500:
        return 'Think twice'
    else:
        return 'No thanks'

# %%
df['MyValuePerception'] = df.apply(lambda x: my_price_perception(x['price'], x['cut']), axis=1)
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        MyValuePerception
# ...

# %%
df.head(100)['MyValuePerception'].value_counts()
# Out:
# MyValuePerception
# Buy                  52
# Worth it, buy now    38
# No thanks            10
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
def color_and_cut_selection(df, sort_variables):

    df = df.copy()
    df = (df
            .query('color in ["E"]')
            .query('cut == "Ideal" | cut == "Premium"')
            .sort_values(by=sort_variables, ascending=False)

    )
    return df

# %%
df.pipe(color_and_cut_selection, sort_variables=['cut', 'carat'])
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 22428   3.05  Premium     E      I1   60.9   58.0  10453  9.26  9.25  5.66
# 27016   2.71  Premium     E     SI2   60.4   59.0  17146  9.13  9.03  5.48
# 27005   2.57  Premium     E     SI2   61.3   60.0  17116  8.82  8.73  5.38
# 22440   2.46  Premium     E     SI2   59.7   59.0  10470  8.82  8.76  5.25
# 27508   2.19  Premium     E     SI2   62.4   61.0  18232  8.31  8.23  5.16
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 50295   0.23    Ideal     E     VS2   62.6   57.0    543  3.92  3.88  2.44
# 52301   0.23    Ideal     E     VS2   61.7   55.0    548  3.98  4.00  2.46
# 52302   0.23    Ideal     E     VS2   61.8   54.0    548  3.94  3.96  2.44
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367  3.86  3.84  2.30
# 31599   0.20    Ideal     E     VS2   62.2   57.0    367  3.76  3.73  2.33
#
# [6240 rows x 10 columns]

# %% [markdown]
# ### Sort data

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df['color'].unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
df.sort_values(by=['color'])
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 7817    1.00  Very Good     D     SI2   63.5   59.0   4295  6.35  6.32  4.02
# 7816    1.00       Good     D     SI2   57.8   58.0   4295  6.61  6.55  3.80
# 7815    1.00  Very Good     D     SI2   61.5   63.0   4295  6.32  6.27  3.87
# 7809    0.56      Ideal     D      IF   61.9   57.0   4293  5.28  5.31  3.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4861    1.00    Premium     J     SI1   60.8   58.0   3712  6.39  6.44  3.90
# 18421   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 18423   1.50  Very Good     J     VS2   62.6   58.0   7492  7.25  7.29  4.55
# 42108   0.65      Ideal     J     SI1   61.4   55.0   1276  5.58  5.62  3.44
# 14123   1.30      Ideal     J     SI1   61.5   55.0   5728  7.03  7.06  4.33
#
# [53940 rows x 10 columns]

# %%
df.sort_values(by=['color'], ascending=False)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 48371   0.74      Ideal     J     SI1   61.7   56.0   1963  5.81  5.85  3.60
# 28644   0.33      Ideal     J     VS1   62.1   55.0    434  4.41  4.44  2.75
# 41323   0.65      Ideal     J     SI1   61.9   54.0   1214  5.60  5.62  3.47
# 48144   0.70  Very Good     J     VS2   63.2   61.0   1940  5.62  5.59  3.54
# 2424    0.92      Ideal     J     SI1   61.7   57.0   3181  6.21  6.26  3.85
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 18144   1.24    Premium     D     SI1   62.4   59.0   7351  6.82  6.86  4.27
# 33658   0.35  Very Good     D    VVS2   60.0   58.0    835  4.57  4.59  2.75
# 33657   0.30      Ideal     D     VS1   61.0   57.0    835  4.32  4.31  2.63
# 33656   0.30      Ideal     D     VS1   62.2   56.0    835  4.31  4.27  2.67
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.sort_values(by=['color', 'price'], inplace=True)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Chaining methods

# %%
df_processed = (df
                .query("cut in ['Ideal', 'Premium']")
                .rename(mapper={'price':'FinalPrice'}, axis=1)
                .sort_values(by=['cut', 'FinalPrice'], ascending=True)
                .filter(['cut', 'color', 'FinalPrice'])
                .replace(to_replace={"Premium":"Most Amazing Ever"})

)

df_processed
# Out:
#                      cut color  FinalPrice
# 0                  Ideal     E         326
# 11                 Ideal     J         340
# 13                 Ideal     J         344
# 16                 Ideal     I         348
# 28262              Ideal     H         357
# ...                  ...   ...         ...
# 27740  Most Amazing Ever     F       18791
# 27742  Most Amazing Ever     H       18795
# 27743  Most Amazing Ever     I       18795
# 27744  Most Amazing Ever     I       18797
# 27749  Most Amazing Ever     I       18823
#
# [35342 rows x 3 columns]

# %% [markdown]
# ### Long format Wide format

# %%
df_long = pd.DataFrame (data= {'City': ['Dublin', 'Dublin', 'Dublin', 'Dublin',
                                        'Cork', 'Cork', 'Cork', 'Cork', 'Galway',
                                        'Galway', 'Galway', 'Galway'],
                                'Day': [1,2,3,4]*3,
                                'AvgTemperature': np.random.randint (10, 30, 12)})
df_long
# Out:
#       City  Day  AvgTemperature
# 0   Dublin    1              26
# 1   Dublin    2              14
# 2   Dublin    3              11
# 3   Dublin    4              28
# 4     Cork    1              17
# 5     Cork    2              25
# 6     Cork    3              15
# 7     Cork    4              19
# 8   Galway    1              18
# 9   Galway    2              24
# 10  Galway    3              11
# 11  Galway    4              18

# %%
pd.pivot_table(data=df_long,
               index=['City'],
               columns=['Day'],
               values='AvgTemperature' )
# Out:
# Day      1   2   3   4
# City
# Cork    17  25  15  19
# Dublin  26  14  11  28
# Galway  18  24  11  18

# %%
pd.pivot_table(data=df_long,
               index='City',
               columns='Day',
               values='AvgTemperature').reset_index().rename_axis(mapper=None, axis=1)
# Out:
#      City   1   2   3   4
# 0    Cork  17  25  15  19
# 1  Dublin  26  14  11  28
# 2  Galway  18  24  11  18

# %%
df_wide = pd.DataFrame(data={'City' : ['Cork', 'Dublin', 'Galway'],
                              'Day1' : [25,21,14],
                              'Day2' : [19,27,18],
                              'Day3' : [23,16,10],
                              'Day4' : [18,21,24]}
                                
                    )
df_wide
# Out:
#      City  Day1  Day2  Day3  Day4
# 0    Cork    25    19    23    18
# 1  Dublin    21    27    16    21
# 2  Galway    14    18    10    24

# %%
pd.melt(frame=df_wide,
        var_name='Day',
        value_name='Average Temperature',
        value_vars=['Day1', 'Day2', 'Day3','Day4'],
        id_vars=['City'])
# Out:
#       City   Day  Average Temperature
# 0     Cork  Day1                   25
# 1   Dublin  Day1                   21
# 2   Galway  Day1                   14
# 3     Cork  Day2                   19
# 4   Dublin  Day2                   27
# 5   Galway  Day2                   18
# 6     Cork  Day3                   23
# 7   Dublin  Day3                   16
# 8   Galway  Day3                   10
# 9     Cork  Day4                   18
# 10  Dublin  Day4                   21
# 11  Galway  Day4                   24

# %%
df = sns.load_dataset('diamonds')
df = df.head(200)
print(df.shape)
df.head(10)
# Out:
# (200, 10)
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.query("cut == 'Ideal' and color == 'E'")
# Out:
#      carat    cut color clarity  depth  table  price     x     y     z
# 0     0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 82    0.26  Ideal     E    VVS2   62.9   58.0    554  4.02  4.06  2.54
# 90    0.70  Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 109   0.59  Ideal     E    VVS2   62.0   55.0   2761  5.38  5.43  3.35
# 111   0.74  Ideal     E     SI2   62.2   56.0   2761  5.80  5.84  3.62
# 118   0.70  Ideal     E     VS2   60.7   58.0   2762  5.73  5.76  3.49
# 121   0.74  Ideal     E     SI1   62.3   54.0   2762  5.80  5.83  3.62
# 149   0.70  Ideal     E     SI1   60.9   57.0   2768  5.73  5.76  3.50
# 173   0.60  Ideal     E     VS1   61.7   55.0   2774  5.41  5.44  3.35
# 174   0.70  Ideal     E     SI1   62.7   55.0   2774  5.68  5.74  3.58
# 179   0.71  Ideal     E     VS2   62.2   57.0   2776  5.79  5.62  3.55
# 180   0.54  Ideal     E    VVS2   61.6   56.0   2776  5.25  5.27  3.24
# ...

# %%
pd.pivot_table(data=df,
               index='cut',
               columns='color',
               values='price', 
               aggfunc='mean' 
)
# Out:
# color                D            E            F            G            H  \
# cut
# Ideal      2213.750000  2458.733333  2765.125000  2386.083333  2764.000000
# Premium    1853.400000  1924.000000  2084.000000  2323.900000  1184.714286
# Very Good  1624.571429  1150.600000  1867.538462  1995.333333  1188.555556
# Good        403.000000  1362.800000  2178.750000  2776.000000   905.800000
# Fair               NaN  1547.000000  2761.000000          NaN  2763.000000
#
# color                I           J
# cut
# Ideal      1082.909091  362.333333
# Premium     911.200000  405.000000
# Very Good   382.000000  754.000000
# Good       1176.666667  344.000000
# Fair               NaN         NaN

# %%
pd.pivot_table(data=df,
               index=['cut', 'color'],
               columns='clarity',
               values='price', 
               fill_value=0,
               aggfunc='max')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.pivot_table(data=df,
#       2                index=['cut', 'color'],
#       3                columns='clarity',
#       4                values='price',
#       5                fill_value=0,
#       6                aggfunc='max')
#
# NameError: name 'df' is not defined

# %%
data = {'Product':['Bread', 'Bread', 'Milk', 'Milk','Milk','Butter','Butter','Butter'],
        'Person':['Anna', 'Anna', 'Brian', 'John', 'John', 'Carl', 'Sarah', 'Anna'],
        'Sales':[200,120,340,124,243,350,500,240],
        'Quantity':[3,5,3,8,2,7,5,4],
        'Margin':[100,20,280,50,100,67,300,200]}
df = pd.DataFrame(data)

# %%
by_group = df.groupby(['Product'])

# %%
for product, frame in by_group:
    print(f"Entries for '{product}' ")
    print("--------------------------")
    print(f"{frame} \n\n")
# Out:
# Entries for '('Bread',)'
# --------------------------
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
#
#
# Entries for '('Butter',)'
# --------------------------
#   Product Person  Sales  Quantity  Margin
# 5  Butter   Carl    350         7      67
# 6  Butter  Sarah    500         5     300
# 7  Butter   Anna    240         4     200
#
#
# Entries for '('Milk',)'
# --------------------------
#   Product Person  Sales  Quantity  Margin
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100

# %%
df
# Out:
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100
# 5  Butter   Carl    350         7      67
# 6  Butter  Sarah    500         5     300
# 7  Butter   Anna    240         4     200

# %%
df
# Out:
#   Product Person  Sales  Quantity  Margin
# 0   Bread   Anna    200         3     100
# 1   Bread   Anna    120         5      20
# 2    Milk  Brian    340         3     280
# 3    Milk   John    124         8      50
# 4    Milk   John    243         2     100
# 5  Butter   Carl    350         7      67
# 6  Butter  Sarah    500         5     300
# 7  Butter   Anna    240         4     200

# %%
df['Person'] = pd.to_numeric(df['Person'], errors='coerce')
df.groupby(by='Product').min().round(2)
# Out:
#         Person  Sales  Quantity  Margin
# Product
# Bread     Anna    120         3      20
# Butter    Anna    240         4      67
# Milk     Brian    124         2      50

# %%
df.groupby(by='Product').describe().round(2)
# Out:
#         Sales                                                    Quantity  \
#         count    mean     std    min    25%    50%    75%    max    count
# Product
# Bread     2.0  160.00   56.57  120.0  140.0  160.0  180.0  200.0      2.0
# Butter    3.0  363.33  130.51  240.0  295.0  350.0  425.0  500.0      3.0
# Milk      3.0  235.67  108.19  124.0  183.5  243.0  291.5  340.0      3.0
#
#                ...           Margin                                      \
#          mean  ...  75%  max  count    mean     std   min    25%    50%
# Product        ...
# Bread    4.00  ...  4.5  5.0    2.0   60.00   56.57  20.0   40.0   60.0
# Butter   5.33  ...  6.0  7.0    3.0  189.00  116.89  67.0  133.5  200.0
# Milk     4.33  ...  5.5  8.0    3.0  143.33  120.97  50.0   75.0  100.0
#
#
#            75%    max
# Product
# Bread     80.0  100.0
# Butter   250.0  300.0
# Milk     190.0  280.0
#
# [3 rows x 24 columns]

# %%
df.groupby(by='Product').describe().round(2).T
# Out:
# Product          Bread  Butter    Milk
# Sales    count    2.00    3.00    3.00
#          mean   160.00  363.33  235.67
#          std     56.57  130.51  108.19
#          min    120.00  240.00  124.00
#          25%    140.00  295.00  183.50
#          50%    160.00  350.00  243.00
#          75%    180.00  425.00  291.50
#          max    200.00  500.00  340.00
# Quantity count    2.00    3.00    3.00
#          mean     4.00    5.33    4.33
#          std      1.41    1.53    3.21
#          min      3.00    4.00    2.00
#          25%      3.50    4.50    2.50
#          50%      4.00    5.00    3.00
#          75%      4.50    6.00    5.50
#          max      5.00    7.00    8.00
# Margin   count    2.00    3.00    3.00
#          mean    60.00  189.00  143.33
#          std     56.57  116.89  120.97
#          min     20.00   67.00   50.00
#          25%     40.00  133.50   75.00
#          50%     60.00  200.00  100.00
#          75%     80.00  250.00  190.00
# ...

# %%
df.groupby(by='Product').describe(include='all').round(2)
# Out:
#         Person                                                  ... Margin  \
#          count unique   top freq mean  std  min  25%  50%  75%  ... unique
# Product                                                         ...
# Bread        2      1  Anna    2  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# Butter       3      3  Carl    1  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# Milk         3      2  John    2  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
#
#
#         top freq    mean     std   min    25%    50%    75%    max
# Product
# Bread   NaN  NaN   60.00   56.57  20.0   40.0   60.0   80.0  100.0
# Butter  NaN  NaN  189.00  116.89  67.0  133.5  200.0  250.0  300.0
# Milk    NaN  NaN  143.33  120.97  50.0   75.0  100.0  190.0  280.0
#
# [3 rows x 44 columns]

# %%
df.groupby(by=['Person', 'Product']).describe().round(1)
# Out:
#                Sales                                                 Quantity  \
#                count   mean   std    min    25%    50%    75%    max    count
# Person Product
# Anna   Bread     2.0  160.0  56.6  120.0  140.0  160.0  180.0  200.0      2.0
#        Butter    1.0  240.0   NaN  240.0  240.0  240.0  240.0  240.0      1.0
# Brian  Milk      1.0  340.0   NaN  340.0  340.0  340.0  340.0  340.0      1.0
# Carl   Butter    1.0  350.0   NaN  350.0  350.0  350.0  350.0  350.0      1.0
# John   Milk      2.0  183.5  84.1  124.0  153.8  183.5  213.2  243.0      2.0
# Sarah  Butter    1.0  500.0   NaN  500.0  500.0  500.0  500.0  500.0      1.0
#
#                      ...           Margin                                    \
#                mean  ...  75%  max  count   mean   std    min    25%    50%
# Person Product       ...
# Anna   Bread    4.0  ...  4.5  5.0    2.0   60.0  56.6   20.0   40.0   60.0
# ...

# %%
def sales_forecast_next_month(x):
  return x.sum() * 1.5
(df
  .groupby(by=['Product'])
  ['Sales']
  .agg(['sum', 'mean', sales_forecast_next_month])
  .round(2)
  )
# Out:
#           sum    mean  sales_forecast_next_month
# Product
# Bread     320  160.00                      480.0
# Butter   1090  363.33                     1635.0
# Milk      707  235.67                     1060.5

# %%
df
# Out:
#   Product  Person  Sales  Quantity  Margin
# 0   Bread     NaN    200         3     100
# 1   Bread     NaN    120         5      20
# 2    Milk     NaN    340         3     280
# 3    Milk     NaN    124         8      50
# 4    Milk     NaN    243         2     100
# 5  Butter     NaN    350         7      67
# 6  Butter     NaN    500         5     300
# 7  Butter     NaN    240         4     200

# %%
df_report = (df
            .groupby(by=['Product'])
            .agg (Total_of_Margin= ('Margin', 'sum'),
                Total_of_Sales= ('Sales', 'sum'),
                Avg_of_Sales= ('Sales', 'mean'), 
                Quantity=('Quantity', 'sum'),
                Number_of_People_Selling=('Person', 'nunique'),
                Team=('Person', 'unique'),
                SalesForecastForNextMonth=('Sales', sales_forecast_next_month)
            )
            .reset_index()
            )
df_report
# Out:
#   Product  Total_of_Margin  Total_of_Sales  Avg_of_Sales  Quantity  \
# 0   Bread              120             320    160.000000         8
# 1  Butter              567            1090    363.333333        16
# 2    Milk              430             707    235.666667        13
#
#    Number_of_People_Selling                 Team  SalesForecastForNextMonth
# 0                         1               [Anna]                      480.0
# 1                         3  [Carl, Sarah, Anna]                     1635.0
# 2                         2        [Brian, John]                     1060.5

# %%
(df
  .groupby(by=['Person', 'Product'])
  .agg(Total_of_Sales=('Sales', 'sum'),
       Quantity=('Quantity', 'sum'),
       Total_of_Margin=('Margin', 'sum'))
       .reset_index()
       )
# Out:
#   Person Product  Total_of_Sales  Quantity  Total_of_Margin
# 0   Anna   Bread             320         8              120
# 1   Anna  Butter             240         4              200
# 2  Brian    Milk             340         3              280
# 3   Carl  Butter             350         7               67
# 4   John    Milk             367        10              150
# 5  Sarah  Butter             500         5              300

# %% [markdown]
# ### Concatenate (axis=0), Merge

# %%
df1 = pd.DataFrame(data=1,
                   columns=['A', 'B'],
                   index=[0,1,2,3])

df2 = pd.DataFrame(data=2,
                   columns=['A', 'B'],
                   index=[4,5,6,7])

df3 = pd.DataFrame(data=3,
                   columns=['A', 'B'],
                   index=[8,9,10,11])

# %%
df1
# Out:
#    A  B
# 0  1  1
# 1  1  1
# 2  1  1
# 3  1  1

# %%
df2
# Out:
#    A  B
# 4  2  2
# 5  2  2
# 6  2  2
# 7  2  2

# %%
df3
# Out:
#     A  B
# 8   3  3
# 9   3  3
# 10  3  3
# 11  3  3

# %%
pd.concat([df1,df2,df3], axis=0)
# Out:
#     A  B
# 0   1  1
# 1   1  1
# 2   1  1
# 3   1  1
# 4   2  2
# 5   2  2
# 6   2  2
# 7   2  2
# 8   3  3
# 9   3  3
# 10  3  3
# 11  3  3

# %%
pd.concat([df1,df2,df3], axis=1)
# Out:
#       A    B    A    B    A    B
# 0   1.0  1.0  NaN  NaN  NaN  NaN
# 1   1.0  1.0  NaN  NaN  NaN  NaN
# 2   1.0  1.0  NaN  NaN  NaN  NaN
# 3   1.0  1.0  NaN  NaN  NaN  NaN
# 4   NaN  NaN  2.0  2.0  NaN  NaN
# 5   NaN  NaN  2.0  2.0  NaN  NaN
# 6   NaN  NaN  2.0  2.0  NaN  NaN
# 7   NaN  NaN  2.0  2.0  NaN  NaN
# 8   NaN  NaN  NaN  NaN  3.0  3.0
# 9   NaN  NaN  NaN  NaN  3.0  3.0
# 10  NaN  NaN  NaN  NaN  3.0  3.0
# 11  NaN  NaN  NaN  NaN  3.0  3.0

# %%
d_f1 = pd.DataFrame({'key':['K0','K1'],
                   'A':['A0', 'A1'],
                   'B':['B0', 'B1']})

d_f2 = pd.DataFrame({'key':['K0','K2'],
                   'C':['C0', 'C2'],
                   'D':['D0', 'D2']})

# %%
d_f1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1

# %%
d_f2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K2  C2  D2

# %%
pd.merge(d_f1, d_f2, how='left', on='key')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K1  A1  B1  NaN  NaN

# %%
pd.merge(d_f1, d_f2, how='right', on='key')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K2  NaN  NaN  C2  D2

# %%
pd.merge(d_f1, d_f2, how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0

# %%
pd.merge(d_f1, d_f2, how='outer', on='key')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K1   A1   B1  NaN  NaN
# 2  K2  NaN  NaN   C2   D2

# %%
d_f3 = pd.DataFrame({'c_key':['K0','K2'],
                   'C':['C10', 'C20'],
                   'D':['D10', 'D20']})

# %%
pd.merge(d_f1, d_f3, how='inner', left_on='key', right_on='c_key')
# Out:
#   key   A   B c_key    C    D
# 0  K0  A0  B0    K0  C10  D10

# %% [markdown]
# ### Join

# %%
df_left = pd.DataFrame({'A':['A0','A1', 'A2'],
                        'B':['B0', 'B1', 'B2']},
                        index=['K0', 'K1', 'K2'])

df_right = pd.DataFrame({'C':['C0','C2', 'C3'],
                        'D':['D0', 'D2', 'D3']},
                        index=['K0', 'K2', 'K3'])

# %%
df_left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df_right
# Out:
#      C   D
# D0  C0  D0
# D2  C2  D2
# D3  C3  D3

# %%
df_left.join(df_right, how='right')
# Out:
#       A    B   C   D
# D0  NaN  NaN  C0  D0
# D2  NaN  NaN  C2  D2
# D3  NaN  NaN  C3  D3

# %%
df_left.join(df_right, how='left')
# Out:
#      A   B    C    D
# K0  A0  B0  NaN  NaN
# K1  A1  B1  NaN  NaN
# K2  A2  B2  NaN  NaN

# %%
df_left.join(df_right, how='inner')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df_left.join(df_right, how='outer')
# Out:
#       A    B    C    D
# D0  NaN  NaN   C0   D0
# D2  NaN  NaN   C2   D2
# D3  NaN  NaN   C3   D3
# K0   A0   B0  NaN  NaN
# K1   A1   B1  NaN  NaN
# K2   A2   B2  NaN  NaN

# %%
df_result = df_left.join(df_right, how='right')

# %%
df_result.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_result.isna().sum()
#
# NameError: name 'df_result' is not defined

# %%
import statsmodels.api as sm
data = {'values': [1, 3, 2, 5, 4, 7, 6, 9, 8, 10]}
df = pd.DataFrame(data)

# Create the QQ plot
sm.qqplot(df['values'], line='s')

# Set axis labels and title
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.title('QQ Plot')

# Show the plot
plt.show()

# %%
df = sns.load_dataset('penguins')
df.head(50)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
print(df.shape)
df.head()
# Out:
# (344, 7)
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.select_dtypes(include='object').describe(include='all')
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       152     168   168

# %%
for col in df.select_dtypes(include='object').columns:
    print(f"{df[col].value_counts()}")
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
for col in df.select_dtypes(include='object'):
    plt.figure(figsize=(10,4))
    sns.countplot(data=df, x=col)
    plt.title(f"{col} Distribution")
    plt.show()

# %%
df = sns.load_dataset('tips')
print(df.shape)
df.head()
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
for column in df.select_dtypes(include='number').columns:
    # Calculate quartiles
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)

    # Calculate the Interquartile Range (IQR)
    iqr = q3 - q1

    # Calculate the upper bound for outliers using Q3 + 1.5 * IQR
    upper_bound = q3 + 1.5 * iqr

    # Create box plot
    plt.boxplot(df[column])
    plt.axhline(upper_bound, color='r', linestyle='--', label='Upper Bound (Q3 + 1.5 * IQR)')

    # Set labels and title
    plt.xlabel(column)
    plt.ylabel('Values')
    plt.title(f'Box Plot with Upper Bound ({column})')

    # Show legend
    plt.legend()

    # Show the plot
    plt.show()

# %%
for column in df.select_dtypes(include='number').columns:

    sns.histplot(data=df, x=column, kde=True)


    # Calculate quartiles
    q1 = df[column].quantile(0.25)
    q2 = df[column].quantile(0.5)
    q3 = df[column].quantile(0.75)
    q4 = df[column].quantile(1)

    # Calculate the Interquartile Range (IQR)
    iqr = q3 - q1

    # Calculate the upper bound for outliers using Q3 + 1.5 * IQR
    upper_bound = q3 + 1.5 * iqr

    # Create histogram plot
    plt.hist(df[column], bins='auto', edgecolor='black')
    plt.axvline(q1, color='r', linestyle='--', label='q1')
    plt.axvline(q2, color='g', linestyle='--', label='q2')
    plt.axvline(q3, color='b', linestyle='--', label='q3')
    plt.axvline(q4, color='m', linestyle='--', label='q4')
    plt.axvline(upper_bound, color='orange', linestyle='--', label='Upper Bound (Q3 + 1.5 * IQR)')
    plt.axvline(q1 - 1.5 * iqr, color='purple', linestyle='--', label='Lower Bound (Q1 - 1.5 * IQR)')

    # Set labels and title
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram with Quartiles, Upper Bound, and Lower Bound ({column})')

    # Show legend
    plt.legend()

    # Show the plot
    plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000
